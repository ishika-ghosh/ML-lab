# %% [markdown]
# ### Assignment 1:Take a data set in a data frame and plot the bar chart example may be year of Production and the Production Quantity. (Take help of Pandas)

# %%
import pandas as pd 
import matplotlib.pyplot as plt

data={
    "Year of production":['2020','2021','2022','2023'],
    "Production Quantity":[50000,70000,60000,90000]
}
df=pd.DataFrame(data)
x=df['Year of production']
y=df['Production Quantity']
plt.xlabel("year of production")
plt.ylabel("Production quantity")
plt.bar(x,y)
plt.show()

# %% [markdown]
# ### Assignment 2: Take a data set from the above data frame which you have prepared and plot the pie chart. (Take help of Pandas)

# %%
data={
    "Year of production":['2020','2021','2022','2023'],
    "Production Quantity":[50000,70000,60000,90000]
}
df=pd.DataFrame(data)
x=df['Year of production']
y=df['Production Quantity']
plt.pie(y,labels=x)
plt.show()

# %% [markdown]
# ### Assignment 3: Take a csv file with name, employee id and salary. Read the datas of salary and plot the bar Chart with employee name on the x axis and employee salary on the y-axis. Just take 5 records in the csv files.

# %%
df=pd.read_csv("Employee_details.csv")
x=df["Name"]
y=df['Salary']
plt.bar(x,y)
plt.xlabel("name")
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Assignment 4:Take the dirtydata.csv as an input and plot the box-plot for the column duration and find out How many outliers are there?

# %%
df=pd.read_csv('dirtydata.csv')
data=df['Duration']

# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %% [markdown]
# ### Assignment 5: What do you mean by multiple boxplots? Take a data set in a data frame and draw the multiple boxplots. Make a csv file with multiple parameters and then plot multiple box plots for each parameter.

# %%
df=pd.read_csv('nba.csv')

x = df[['Age','Weight','Salary']]

fig = plt.figure(figsize =(6, 5)) 
ax = fig.add_axes([0, 0, 1, 1])
ax.boxplot(x)
plt.show()
